# %%
a=10
b=3
c=a+b
print(c)
# Out:
# 13

# %%
a=2
b=6
c=a<b
print(c)
# Out:
# True

# %%
from typing_extensions import OrderedDict
a=1
b=0
c=a<b
print(c)
# Out:
# False

# %%
x=int(input("enter first number"))
y=int(input("enter second number"))
op=input("enter the operator(+,-,*,/)")
if op=="+":
  print(x+y)
elif op=="-":
  print(x-y)
elif op=="*":
  print(x*y)
elif op=="/":
  print(x/y)
# Out:
# enter first number2
# enter second number4
# enter the operator(+,-,*,/)+
# 6

# %%
import pandas as pd
df= pd.read_csv("/content/sample_data/gender_submission - gender_submission.csv")
print("first five rows of the dataset")
print(df.head())
print("\ncoloum names:")
print(df.coloums.tolist())
print("\nshape of the data set(rows,coloums:):",df.shape)
print(df.types)
print(df.info)
# Out:
# first five rows of the dataset
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
#
# coloum names:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-147360682.py in <cell line: 0>()
#       4 print(df.head())
#       5 print("\ncoloum names:")
# ----> 6 print(df.coloums.tolist())
#       7 print("\nshape of the data set(rows,coloums:):",df.shape)
#       8 print(df.types)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'coloums'

# %%
x=int(input("enter the first number:"))
y=int(input("enter the second number:"))
z=(x,y)
print(z[ : :-1])
# Out:
# enter the first number:4
# enter the second number:6
# (6, 4)

# %%
x=int(input("enter the first number:"))
y=int(input("enter the second number:"))
z=(x+y)
print(int(str(z)[ : :-1]))
# Out:
# enter the first number:8
# enter the second number:5
# 31

# %%
a=int(input("enter a number:"))
if a % 2==0:
   print("it is even")
else:
   print("it is odd")
# Out:
# enter a number:95
# it is odd

# %%
a =int(input("enter a number:"))
b=0
for i in range(2,a):
  if a % i== 0:
   b+=1
   break
  if (b==0):
     print("it is prime number")
  else:
     print("it is not a prime number")
# Out:
# enter a number:3
# it is prime number

# %%
a =eval(input("enter a number;"))
print (max(a))
# Out:
# enter a number;[2,4,6,78]
# 78

# %%
a =int(input("table value:"))
b =int(input("enter the number of multiples:"))
for i in range(1,b+1):
  print(a,"x",i,"=",a*i)
# Out:
# table value:4
# enter the number of multiples:7
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28

# %%
for i in range(5):
  print(i* "*")
  print("\n")
# Out:
# *
#
#
# **
#
#
# ***
#
#
# ****

# %%
b =int(input("enter a number:"))
c = 1
for i in range(1,b+1):
  c*=i
  print(c)
# Out:
# enter a number:4
# 1
# 2
# 6
# 24
